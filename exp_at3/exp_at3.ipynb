# %%
import plot
options = plot.Options(
	save = False,
	plot_db = False,
	plot_ycsb = False,
	plot_io = False,
	plot_cpu = False,
	plot_at3 = False,
	plot_at3_script = False,
	plot_at3_write_ratio=True)

plot.plotFiles(plot.getFiles('exp_at3'), options)
# Out:
# ######################################################
# Graphs from file "exp_at3/jobs1_cache.out":
# ######################################################
# Graphs from file "exp_at3/jobs1_directio.out":
# ######################################################
# Graphs from file "exp_at3/jobs2_cache.out":
# ######################################################
# Graphs from file "exp_at3/jobs2_directio.out":
# ######################################################
# Graphs from file "exp_at3/jobs3_cache.out":
# ######################################################
# Graphs from file "exp_at3/jobs3_directio.out":
# ######################################################
# Graphs from file "exp_at3/jobs4_cache.out":
# ######################################################
# Graphs from file "exp_at3/jobs4_directio.out":
# ######################################################
# Graphs from file "exp_at3/jobs5_cache.out":
# ######################################################
# ...
