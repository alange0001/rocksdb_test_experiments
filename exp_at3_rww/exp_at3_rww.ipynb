# %%
import plot
options = plot.Options(
	save = False,
	graphTickMajor=2,
	graphTickMinor=4,
	plot_io_norm=True)

plot.plotFiles(plot.getFiles('exp_at3_rww'), options)
# Out:
# ######################################################
# Graphs from file "exp_at3_rww/jobs4_rww_bs4_cache.out":
# ######################################################
# Graphs from file "exp_at3_rww/jobs4_rww_bs4_directio.out":
# ######################################################
# Graphs from file "exp_at3_rww/jobs4_rww_bs8_cache.out":
# ######################################################
# Graphs from file "exp_at3_rww/jobs4_rww_bs8_directio.out":
# ######################################################
# Graphs from file "exp_at3_rww/jobs4_rww_bs128_cache.out":
# ######################################################
# Graphs from file "exp_at3_rww/jobs4_rww_bs128_directio.out":
# ######################################################
# Graphs from file "exp_at3_rww/jobs4_rww_bs256_cache.out":
# ######################################################
# Graphs from file "exp_at3_rww/jobs4_rww_bs256_directio.out":
# ######################################################
# ...
