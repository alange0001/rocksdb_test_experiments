# %% [markdown]
# # DB Experiments 3, Tuning 07, Cloud
#
# Google Cloud:
# * Machine type: e2-standard-8 (8 vCPUs, 32 GB memory)
#   * SSD persistent disk (70GB)
# * Zone: us-central1-a
#
# Using:
# * Rocksdb_test v1.12
#   * Access_time3 using libaio engine
# * YCSB with RocksDB 6.15

# %%
import sys; sys.path.append('../..')  # using plot.py from the parent directory
import re
import plot
label = lambda f: f'depth={f._params["at_iodepth[0]"]}{", dsync" if f._params.get("at_o_dsync[0]") == "true" else ""}, bs={f._params["at_block_size[0]"]}'
options = plot.Options(
    #save=True,
    #formats=['png'],
    #print_params=True,
    plot_nothing=True,
    plot_io=True,
    plot_cpu=True,
    plot_at3=True,
    plot_at3_script=True,
    plot_db=True,
    #plot_pressure=True,
    #pressure_decreased=False,
    #print_pressure_values=True,
    plot_ycsb_lsm_size=True,
    plot_ycsb_lsm_details=True,
    plot_ycsb_lsm_summary=True,
    #plot_containers_io=True,
    #plot_smart_utilization=True,
    db_mean_interval=5,
    #plot_all_pressure=True,
    all_pressure_label=label
)
options_i5 = options(db_mean_interval=5)
exp_dir = '.'

# %%
files = plot.getFiles(exp_dir, str_filter='07_google1-')
plot.plotFiles(files, options)
# Out:
# Graphs from file "./07_google1-ycsb_workloada.out.xz":
# Database Performance: ./07_google1-ycsb_workloada.out.xz
# I/O Performance: ./07_google1-ycsb_workloada.out.xz
# CPU Utilization: ./07_google1-ycsb_workloada.out.xz
# access_time3 Performance: ./07_google1-ycsb_workloada.out.xz
# Concurrent Workloads (at3_script): ./07_google1-ycsb_workloada.out.xz
# LSM-tree level sizes: ./07_google1-ycsb_workloada.out.xz
# LSM-tree details: ./07_google1-ycsb_workloada.out.xz
# LSM-tree summary: ./07_google1-ycsb_workloada.out.xz
# Graphs from file "./07_google1-ycsb_workloadb.out.xz":
# Database Performance: ./07_google1-ycsb_workloadb.out.xz
# I/O Performance: ./07_google1-ycsb_workloadb.out.xz
# CPU Utilization: ./07_google1-ycsb_workloadb.out.xz
# access_time3 Performance: ./07_google1-ycsb_workloadb.out.xz
# Concurrent Workloads (at3_script): ./07_google1-ycsb_workloadb.out.xz
# LSM-tree level sizes: ./07_google1-ycsb_workloadb.out.xz
# LSM-tree details: ./07_google1-ycsb_workloadb.out.xz
# LSM-tree summary: ./07_google1-ycsb_workloadb.out.xz

# %%
files = plot.getFiles(exp_dir, str_filter='07_google2-ycsb_workload')
plot.plotFiles(files, options)
# Out:
# Graphs from file "./07_google2-ycsb_workloada.out.xz":
# Database Performance: ./07_google2-ycsb_workloada.out.xz
# I/O Performance: ./07_google2-ycsb_workloada.out.xz
# CPU Utilization: ./07_google2-ycsb_workloada.out.xz
# access_time3 Performance: ./07_google2-ycsb_workloada.out.xz
# Concurrent Workloads (at3_script): ./07_google2-ycsb_workloada.out.xz
# LSM-tree level sizes: ./07_google2-ycsb_workloada.out.xz
# LSM-tree details: ./07_google2-ycsb_workloada.out.xz
# LSM-tree summary: ./07_google2-ycsb_workloada.out.xz
# Graphs from file "./07_google2-ycsb_workloadb.out.xz":
# Database Performance: ./07_google2-ycsb_workloadb.out.xz
# I/O Performance: ./07_google2-ycsb_workloadb.out.xz
# CPU Utilization: ./07_google2-ycsb_workloadb.out.xz
# access_time3 Performance: ./07_google2-ycsb_workloadb.out.xz
# Concurrent Workloads (at3_script): ./07_google2-ycsb_workloadb.out.xz
# LSM-tree level sizes: ./07_google2-ycsb_workloadb.out.xz
# LSM-tree details: ./07_google2-ycsb_workloadb.out.xz
# LSM-tree summary: ./07_google2-ycsb_workloadb.out.xz
