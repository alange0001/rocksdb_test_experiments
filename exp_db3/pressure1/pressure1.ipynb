# %% [markdown]
# # DB Experiments 3, Tuning 07, Pressure1
#
# Devices:
# * s980pro250: Samsung 980 PRO 250GB
#   * /dev/nvmeXn1p1 (all disk) on /media/auto/s980pro250 type ext4 (rw,relatime,discard)
# * s970evp250: Samsung 970 EVO Plus 250GB
#   * /dev/nvmeXn1p1 (all disk) on /media/auto/s970evp250 type ext4 (rw,relatime,discard)
# * s970evo500: Samsung 970 EVO 500GB
#   * /dev/nvmeXn1p1 (all disk) on /media/auto/s970evo500 type ext4 (rw,relatime,discard)
#
# Kernels:
# * k504: Ubuntu 20.04 Kernel 5.4
# * k508: Ubuntu 20.04 Kernel 5.8
#
# Using:
# * Rocksdb_test v1.11
# * YCSB with RocksDB 6.15

# %%
import sys; sys.path.append('../..')  # using plot.py from the parent directory
import re
import plot
options = plot.Options(
    #save=True,
    #formats=['png'],
    #print_params=True,
    plot_nothing=True,
    #plot_io=True,
    #plot_cpu=True,
    #plot_at3=True,
    #plot_at3_script=True,
    #plot_db=True,
    #plot_pressure=True,
    #pressure_decreased=False,
    #print_pressure_values=True,
    #plot_ycsb_lsm_size=True,
    #plot_ycsb_lsm_details=True,
    #plot_ycsb_lsm_summary=True,
    #plot_containers_io=True,
    #plot_smart_utilization=True,
    db_mean_interval=2,
    plot_all_pressure=True
)
options_i5 = options(db_mean_interval=5)
exp_dir = '.'

# %% [markdown]
# ## Concurrent Workloads (W)
#
# * 25 concurrent workloads (w1 to w25)
# * 4 instance of access_time3 using read/write operations with O_DIRECT and O_DSYNC

# %%
files = plot.getFiles(exp_dir, list_filter=['-at3', '_bs'])
plot.plotFiles([ files[0] ], options(plot_nothing=True, plot_at3_script=True))
# Out:
# Graphs from file "./07_k504_s970evo500-ycsb_workloada-at3_bs4_directio.out.xz":
# Concurrent Workloads (at3_script): ./07_k504_s970evo500-ycsb_workloada-at3_bs4_directio.out.xz

# %% [markdown]
# ## YCSB workload A, Kernel 5.4, Device 970 EVO 500GB

# %%
k, d, w = 'k504', 's970evo500', 'workloada'
files = plot.getFiles(exp_dir, str_filter=f'07_{k}_{d}-ycsb_{w}-at3')
plot.plotFiles(files, options, allfiles=f'{exp_dir}/07_{k}_{d}-ycsb_{w}-at3_all')
# Out:
# Graphs from file "./07_k504_s970evo500-ycsb_workloada-at3_bs4_directio.out.xz":
# Graphs from file "./07_k504_s970evo500-ycsb_workloada-at3_bs8_directio.out.xz":
# Graphs from file "./07_k504_s970evo500-ycsb_workloada-at3_bs16_directio.out.xz":
# Graphs from file "./07_k504_s970evo500-ycsb_workloada-at3_bs32_directio.out.xz":
# Graphs from file "./07_k504_s970evo500-ycsb_workloada-at3_bs64_directio.out.xz":
# Graphs from file "./07_k504_s970evo500-ycsb_workloada-at3_bs128_directio.out.xz":
# Graphs from file "./07_k504_s970evo500-ycsb_workloada-at3_bs256_directio.out.xz":
# Graphs from file "./07_k504_s970evo500-ycsb_workloada-at3_bs512_directio.out.xz":
# AllFiles Graphs:

# %% [markdown]
# ## YCSB workload A, Kernel 5.8, Device 970 EVO 500GB

# %%
k, d, w = 'k508', 's970evo500', 'workloada'
files = plot.getFiles(exp_dir, str_filter=f'07_{k}_{d}-ycsb_{w}-at3')
plot.plotFiles(files, options, allfiles=f'{exp_dir}/07_{k}_{d}-ycsb_{w}-at3_all')
# Out:
# Graphs from file "./07_k508_s970evo500-ycsb_workloada-at3_bs4_directio.out.xz":
# Graphs from file "./07_k508_s970evo500-ycsb_workloada-at3_bs8_directio.out.xz":
# Graphs from file "./07_k508_s970evo500-ycsb_workloada-at3_bs16_directio.out.xz":
# Graphs from file "./07_k508_s970evo500-ycsb_workloada-at3_bs32_directio.out.xz":
# Graphs from file "./07_k508_s970evo500-ycsb_workloada-at3_bs64_directio.out.xz":
# Graphs from file "./07_k508_s970evo500-ycsb_workloada-at3_bs128_directio.out.xz":
# Graphs from file "./07_k508_s970evo500-ycsb_workloada-at3_bs256_directio.out.xz":
# Graphs from file "./07_k508_s970evo500-ycsb_workloada-at3_bs512_directio.out.xz":
# AllFiles Graphs:

# %% [markdown]
# ## YCSB workload B, Kernel 5.4, Device 970 EVO 500GB

# %%
k, d, w = 'k504', 's970evo500', 'workloadb'
files = plot.getFiles(exp_dir, str_filter=f'07_{k}_{d}-ycsb_{w}-at3')
plot.plotFiles(files, options, allfiles=f'{exp_dir}/07_{k}_{d}-ycsb_{w}-at3_all')
# Out:
# Graphs from file "./07_k504_s970evo500-ycsb_workloadb-at3_bs4_directio.out.xz":
# Graphs from file "./07_k504_s970evo500-ycsb_workloadb-at3_bs8_directio.out.xz":
# Graphs from file "./07_k504_s970evo500-ycsb_workloadb-at3_bs16_directio.out.xz":
# Graphs from file "./07_k504_s970evo500-ycsb_workloadb-at3_bs32_directio.out.xz":
# Graphs from file "./07_k504_s970evo500-ycsb_workloadb-at3_bs64_directio.out.xz":
# Graphs from file "./07_k504_s970evo500-ycsb_workloadb-at3_bs128_directio.out.xz":
# Graphs from file "./07_k504_s970evo500-ycsb_workloadb-at3_bs256_directio.out.xz":
# Graphs from file "./07_k504_s970evo500-ycsb_workloadb-at3_bs512_directio.out.xz":
# AllFiles Graphs:

# %% [markdown]
# ## YCSB workload B, Kernel 5.8, Device 970 EVO 500GB

# %%
k, d, w = 'k508', 's970evo500', 'workloadb'
files = plot.getFiles(exp_dir, str_filter=f'07_{k}_{d}-ycsb_{w}-at3')
plot.plotFiles(files, options, allfiles=f'{exp_dir}/07_{k}_{d}-ycsb_{w}-at3_all')
# Out:
# Graphs from file "./07_k508_s970evo500-ycsb_workloadb-at3_bs4_directio.out.xz":
# Graphs from file "./07_k508_s970evo500-ycsb_workloadb-at3_bs8_directio.out.xz":
# Graphs from file "./07_k508_s970evo500-ycsb_workloadb-at3_bs16_directio.out.xz":
# Graphs from file "./07_k508_s970evo500-ycsb_workloadb-at3_bs32_directio.out.xz":
# Graphs from file "./07_k508_s970evo500-ycsb_workloadb-at3_bs64_directio.out.xz":
# Graphs from file "./07_k508_s970evo500-ycsb_workloadb-at3_bs128_directio.out.xz":
# Graphs from file "./07_k508_s970evo500-ycsb_workloadb-at3_bs256_directio.out.xz":
# Graphs from file "./07_k508_s970evo500-ycsb_workloadb-at3_bs512_directio.out.xz":
# AllFiles Graphs:

# %% [markdown]
# ## YCSB workload A, Kernel 5.4, Device 970 EVO Plus 250GB

# %%
k, d, w = 'k504', 's970evp250', 'workloada'
files = plot.getFiles(exp_dir, str_filter=f'07_{k}_{d}-ycsb_{w}-at3')
plot.plotFiles(files, options, allfiles=f'{exp_dir}/07_{k}_{d}-ycsb_{w}-at3_all')
# Out:
# Graphs from file "./07_k504_s970evp250-ycsb_workloada-at3_bs4_directio.out.xz":
# Graphs from file "./07_k504_s970evp250-ycsb_workloada-at3_bs8_directio.out.xz":
# Graphs from file "./07_k504_s970evp250-ycsb_workloada-at3_bs16_directio.out.xz":
# Graphs from file "./07_k504_s970evp250-ycsb_workloada-at3_bs32_directio.out.xz":
# Graphs from file "./07_k504_s970evp250-ycsb_workloada-at3_bs64_directio.out.xz":
# Graphs from file "./07_k504_s970evp250-ycsb_workloada-at3_bs128_directio.out.xz":
# Graphs from file "./07_k504_s970evp250-ycsb_workloada-at3_bs256_directio.out.xz":
# Graphs from file "./07_k504_s970evp250-ycsb_workloada-at3_bs512_directio.out.xz":
# AllFiles Graphs:

# %% [markdown]
# ## YCSB workload A, Kernel 5.8, Device 970 EVO Plus 250GB

# %%
k, d, w = 'k508', 's970evp250', 'workloada'
files = plot.getFiles(exp_dir, str_filter=f'07_{k}_{d}-ycsb_{w}-at3')
plot.plotFiles(files, options, allfiles=f'{exp_dir}/07_{k}_{d}-ycsb_{w}-at3_all')
# Out:
# Graphs from file "./07_k508_s970evp250-ycsb_workloada-at3_bs4_directio.out.xz":
# Graphs from file "./07_k508_s970evp250-ycsb_workloada-at3_bs8_directio.out.xz":
# Graphs from file "./07_k508_s970evp250-ycsb_workloada-at3_bs16_directio.out.xz":
# Graphs from file "./07_k508_s970evp250-ycsb_workloada-at3_bs32_directio.out.xz":
# Graphs from file "./07_k508_s970evp250-ycsb_workloada-at3_bs64_directio.out.xz":
# Graphs from file "./07_k508_s970evp250-ycsb_workloada-at3_bs128_directio.out.xz":
# Graphs from file "./07_k508_s970evp250-ycsb_workloada-at3_bs256_directio.out.xz":
# Graphs from file "./07_k508_s970evp250-ycsb_workloada-at3_bs512_directio.out.xz":
# AllFiles Graphs:

# %% [markdown]
# ## YCSB workload B, Kernel 5.4, Device 970 EVO Plus 250GB

# %%
k, d, w = 'k504', 's970evp250', 'workloadb'
files = plot.getFiles(exp_dir, str_filter=f'07_{k}_{d}-ycsb_{w}-at3')
plot.plotFiles(files, options, allfiles=f'{exp_dir}/07_{k}_{d}-ycsb_{w}-at3_all')
# Out:
# Graphs from file "./07_k504_s970evp250-ycsb_workloadb-at3_bs4_directio.out.xz":
# Graphs from file "./07_k504_s970evp250-ycsb_workloadb-at3_bs8_directio.out.xz":
# Graphs from file "./07_k504_s970evp250-ycsb_workloadb-at3_bs16_directio.out.xz":
# Graphs from file "./07_k504_s970evp250-ycsb_workloadb-at3_bs32_directio.out.xz":
# Graphs from file "./07_k504_s970evp250-ycsb_workloadb-at3_bs64_directio.out.xz":
# Graphs from file "./07_k504_s970evp250-ycsb_workloadb-at3_bs128_directio.out.xz":
# Graphs from file "./07_k504_s970evp250-ycsb_workloadb-at3_bs256_directio.out.xz":
# Graphs from file "./07_k504_s970evp250-ycsb_workloadb-at3_bs512_directio.out.xz":
# AllFiles Graphs:

# %% [markdown]
# ## YCSB workload B, Kernel 5.8, Device 970 EVO Plus 250GB

# %%
k, d, w = 'k508', 's970evp250', 'workloadb'
files = plot.getFiles(exp_dir, str_filter=f'07_{k}_{d}-ycsb_{w}-at3')
plot.plotFiles(files, options, allfiles=f'{exp_dir}/07_{k}_{d}-ycsb_{w}-at3_all')
# Out:
# Graphs from file "./07_k508_s970evp250-ycsb_workloadb-at3_bs4_directio.out.xz":
# Graphs from file "./07_k508_s970evp250-ycsb_workloadb-at3_bs8_directio.out.xz":
# Graphs from file "./07_k508_s970evp250-ycsb_workloadb-at3_bs16_directio.out.xz":
# Graphs from file "./07_k508_s970evp250-ycsb_workloadb-at3_bs32_directio.out.xz":
# Graphs from file "./07_k508_s970evp250-ycsb_workloadb-at3_bs64_directio.out.xz":
# Graphs from file "./07_k508_s970evp250-ycsb_workloadb-at3_bs128_directio.out.xz":
# Graphs from file "./07_k508_s970evp250-ycsb_workloadb-at3_bs256_directio.out.xz":
# Graphs from file "./07_k508_s970evp250-ycsb_workloadb-at3_bs512_directio.out.xz":
# AllFiles Graphs:

# %% [markdown]
# ## YCSB workload A, Kernel 5.4, Device 980 PRO 250GB

# %%
k, d, w = 'k504', 's980pro250', 'workloada'
files = plot.getFiles(exp_dir, str_filter=f'07_{k}_{d}-ycsb_{w}-at3')
plot.plotFiles(files, options, allfiles=f'{exp_dir}/07_{k}_{d}-ycsb_{w}-at3_all')
# Out:
# Graphs from file "./07_k504_s980pro250-ycsb_workloada-at3_bs4_directio.out.xz":
# Graphs from file "./07_k504_s980pro250-ycsb_workloada-at3_bs8_directio.out.xz":
# Graphs from file "./07_k504_s980pro250-ycsb_workloada-at3_bs16_directio.out.xz":
# Graphs from file "./07_k504_s980pro250-ycsb_workloada-at3_bs32_directio.out.xz":
# Graphs from file "./07_k504_s980pro250-ycsb_workloada-at3_bs64_directio.out.xz":
# Graphs from file "./07_k504_s980pro250-ycsb_workloada-at3_bs128_directio.out.xz":
# Graphs from file "./07_k504_s980pro250-ycsb_workloada-at3_bs256_directio.out.xz":
# Graphs from file "./07_k504_s980pro250-ycsb_workloada-at3_bs512_directio.out.xz":
# AllFiles Graphs:

# %% [markdown]
# ## YCSB workload A, Kernel 5.8, Device 980 PRO 250GB

# %%
k, d, w = 'k508', 's980pro250', 'workloada'
files = plot.getFiles(exp_dir, str_filter=f'07_{k}_{d}-ycsb_{w}-at3')
plot.plotFiles(files, options, allfiles=f'{exp_dir}/07_{k}_{d}-ycsb_{w}-at3_all')
# Out:
# Graphs from file "./07_k508_s980pro250-ycsb_workloada-at3_bs4_directio.out.xz":
# Graphs from file "./07_k508_s980pro250-ycsb_workloada-at3_bs8_directio.out.xz":
# Graphs from file "./07_k508_s980pro250-ycsb_workloada-at3_bs16_directio.out.xz":
# Graphs from file "./07_k508_s980pro250-ycsb_workloada-at3_bs32_directio.out.xz":
# Graphs from file "./07_k508_s980pro250-ycsb_workloada-at3_bs64_directio.out.xz":
# Graphs from file "./07_k508_s980pro250-ycsb_workloada-at3_bs128_directio.out.xz":
# Graphs from file "./07_k508_s980pro250-ycsb_workloada-at3_bs256_directio.out.xz":
# Graphs from file "./07_k508_s980pro250-ycsb_workloada-at3_bs512_directio.out.xz":
# AllFiles Graphs:

# %% [markdown]
# ## YCSB workload B, Kernel 5.4, Device 980 PRO 250GB

# %%
k, d, w = 'k504', 's980pro250', 'workloadb'
files = plot.getFiles(exp_dir, str_filter=f'07_{k}_{d}-ycsb_{w}-at3')
plot.plotFiles(files, options, allfiles=f'{exp_dir}/07_{k}_{d}-ycsb_{w}-at3_all')
# Out:
# Graphs from file "./07_k504_s980pro250-ycsb_workloadb-at3_bs4_directio.out.xz":
# Graphs from file "./07_k504_s980pro250-ycsb_workloadb-at3_bs8_directio.out.xz":
# Graphs from file "./07_k504_s980pro250-ycsb_workloadb-at3_bs16_directio.out.xz":
# Graphs from file "./07_k504_s980pro250-ycsb_workloadb-at3_bs32_directio.out.xz":
# Graphs from file "./07_k504_s980pro250-ycsb_workloadb-at3_bs64_directio.out.xz":
# Graphs from file "./07_k504_s980pro250-ycsb_workloadb-at3_bs128_directio.out.xz":
# Graphs from file "./07_k504_s980pro250-ycsb_workloadb-at3_bs256_directio.out.xz":
# Graphs from file "./07_k504_s980pro250-ycsb_workloadb-at3_bs512_directio.out.xz":
# AllFiles Graphs:

# %% [markdown]
# ## YCSB workload B, Kernel 5.8, Device 980 PRO 250GB

# %%
k, d, w = 'k508', 's980pro250', 'workloadb'
files = plot.getFiles(exp_dir, str_filter=f'07_{k}_{d}-ycsb_{w}-at3')
plot.plotFiles(files, options, allfiles=f'{exp_dir}/07_{k}_{d}-ycsb_{w}-at3_all')
# Out:
# Graphs from file "./07_k508_s980pro250-ycsb_workloadb-at3_bs4_directio.out.xz":
# Graphs from file "./07_k508_s980pro250-ycsb_workloadb-at3_bs8_directio.out.xz":
# Graphs from file "./07_k508_s980pro250-ycsb_workloadb-at3_bs16_directio.out.xz":
# Graphs from file "./07_k508_s980pro250-ycsb_workloadb-at3_bs32_directio.out.xz":
# Graphs from file "./07_k508_s980pro250-ycsb_workloadb-at3_bs64_directio.out.xz":
# Graphs from file "./07_k508_s980pro250-ycsb_workloadb-at3_bs128_directio.out.xz":
# Graphs from file "./07_k508_s980pro250-ycsb_workloadb-at3_bs256_directio.out.xz":
# Graphs from file "./07_k508_s980pro250-ycsb_workloadb-at3_bs512_directio.out.xz":
# AllFiles Graphs:
