# %% [markdown]
# # Tune 3
#
# * Device: Samsung 980 PRO 250GB
#   * /dev/nvme0n1p1 (all disk) on /media/auto/s980pro250 type ext4 (rw,relatime,discard)
#
# Using:
# * Rocksdb_test v1.11
# * YCSB with RocksDB 6.15

# %%
import sys; sys.path.append('../..')  # using plot.py from the parent directory
import plot
options = plot.Options(
    save=False,
    formats=['png'],
    plot_nothing=True,
    plot_io=False,
    plot_cpu=False,
    plot_db=True,
    plot_pressure=True,
    pressure_decreased=False,
    print_pressure_values=True,
    plot_ycsb_lsm_size=True,
    plot_ycsb_lsm_details=False,
    plot_ycsb_lsm_summary=False,
    plot_smart_utilization=True,
    db_mean_interval=2)
options.db_ylim = [0,  None]

exp_dir='.'

# %% [markdown]
# 01 - DB Quali options, 2GB cache

# %%
files = plot.getFiles(exp_dir, str_filter='01_')
plot.plotFiles(files, options)
# Out:
# ######################################################
# Graphs from file "./01_ycsb_create.out.xz":
# ######################################################
# Graphs from file "./01_ycsb_workloadb.out.xz":

# %%
files = plot.getFiles(exp_dir, str_filter='02_')
plot.plotFiles(files, options)
# Out:
# ######################################################
# Graphs from file "./02_ycsb_create.out.xz":
# ######################################################
# Graphs from file "./02_ycsb_workloadb.out.xz":

# %%
#files = plot.getFiles(exp_dir, str_filter='03_')
#plot.plotFiles(files, options)

# %%
files = plot.getFiles(exp_dir, str_filter='04_')
plot.plotFiles(files, options)
# Out:
# ######################################################
# Graphs from file "./04_ycsb_create.out.xz":
# ######################################################
# Graphs from file "./04_ycsb_workloadb.out.xz":

# %%
files = plot.getFiles(exp_dir, str_filter='05_')
plot.plotFiles(files, options)
# Out:
# ######################################################
# Graphs from file "./05_ycsb_create.out.xz":
# ######################################################
# Graphs from file "./05_ycsb_workloadb.out.xz":

# %%
files = plot.getFiles(exp_dir, str_filter='06_ycsb_workload')
plot.plotFiles(files, options)
# Out:
# ######################################################
# Graphs from file "./06_ycsb_workloada.out.xz":
# ######################################################
# Graphs from file "./06_ycsb_workloadb.out.xz":

# %%
#files = plot.getFiles(exp_dir, str_filter='06.s970evo500_')
#plot.plotFiles(files, options)

# %%
files = plot.getFiles(exp_dir, str_filter='07_')
plot.plotFiles(files, options)
# Out:
# ######################################################
# Graphs from file "./07_ycsb_create.out.xz":
# ######################################################
# Graphs from file "./07_ycsb_workloada.out.xz":
# ######################################################
# Graphs from file "./07_ycsb_workloadb.out.xz":
