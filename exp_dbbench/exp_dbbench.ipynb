# %%
import plot
options = plot.Options(print_params=True, graphTickMajor=10, graphTickMinor=4)
options.save=True

#plot.plotFiles(['file.out'], options)

plot.plotFiles(plot.getFiles('exp_dbbench/rrwr'), options)
plot.plotFiles(plot.getFiles('exp_dbbench/mw'), options)
# Out:
# ######################################################
# Graphs from file "exp_dbbench/rrwr/rrwr_dbs1-threads20_writeratio5.out":
#
# Params:
# log_level           : info
# duration            : 16
# warm_period         : 1
# stats_interval      : 5
# num_dbs             : 1
# db_create           : false
# db_mixgraph_params  : --sine_a=1000 --sine_d=4500
# num_ydbs            : 0
# ydb_create          : false
# rocksdb_config_file :
# num_at              : 0
# io_device           : nvme0n1
# db_benchmark[0]     : readrandomwriterandom
# db_path[0]          : /media/auto/work/rocksdb_1
# db_num_keys[0]      : 500000000
# db_num_levels[0]    : 6
# db_cache_size[0]    : 536870912
# db_threads[0]       : 20
# db_readwritepercent[0]: 5
# db_workloadscript[0]:
# db_sine_cycles[0]   : 1
# db_sine_shift[0]    : 0
# db_bench_params[0]  :
# ######################################################
# Graphs from file "exp_dbbench/rrwr/rrwr_dbs1-threads20_writeratio10.out":
#
# Params:
# ...
